# %% [markdown]
# # Telco Customer Churn EDA

# %% [markdown]
# **Each row represents a customer, each column contains customer’s attributes described on the column Metadata.**
#
# **The data set includes information about:**
#
# Customers who left within the last month – the column is called Churn
#
# Services that each customer has signed up for – phone, multiple lines, internet, online security, online backup, device protection, tech support, and streaming TV and movies
#
# Customer account information – how long they’ve been a customer, contract, payment method, paperless billing, monthly charges, and total charges
#
# Demographic info about customers – gender, age range, and if they have partners and dependents
#
# **Data Set link:**
# https://www.kaggle.com/datasets/blastchar/telco-customer-churn

# %% [markdown]
# <img src="1.png" alt="Understanding Telco Customer Churn" width="700"/>

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
import seaborn as sns
# %matplotlib inline

# %%
telecom_data = pd.read_csv('WA_Fn-UseC_-Telco-Customer-Churn.csv')

# %%
telecom_data.head(15)
# Out:
#     customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0   7590-VHVEG  Female              0     Yes         No       1           No
# 1   5575-GNVDE    Male              0      No         No      34          Yes
# 2   3668-QPYBK    Male              0      No         No       2          Yes
# 3   7795-CFOCW    Male              0      No         No      45           No
# 4   9237-HQITU  Female              0      No         No       2          Yes
# 5   9305-CDSKC  Female              0      No         No       8          Yes
# 6   1452-KIOVK    Male              0      No        Yes      22          Yes
# 7   6713-OKOMC  Female              0      No         No      10           No
# 8   7892-POOKP  Female              0     Yes         No      28          Yes
# 9   6388-TABGU    Male              0      No        Yes      62          Yes
# 10  9763-GRSKD    Male              0     Yes        Yes      13          Yes
# ...

# %%
telecom_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
telecom_data.shape
# Out:
# (7043, 21)

# %%
telecom_data.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
telecom_data.nunique()
# Out:
# customerID          7043
# gender                 2
# SeniorCitizen          2
# Partner                2
# Dependents             2
# tenure                73
# PhoneService           2
# MultipleLines          3
# InternetService        3
# OnlineSecurity         3
# OnlineBackup           3
# DeviceProtection       3
# TechSupport            3
# StreamingTV            3
# StreamingMovies        3
# Contract               3
# PaperlessBilling       2
# PaymentMethod          4
# MonthlyCharges      1585
# TotalCharges        6531
# Churn                  2
# dtype: int64

# %%
telecom_data.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %% [markdown]
# **TotalCharges column dtype should be float64**

# %%
telecom_data.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
# Convert total Charges to numeric values 
telecom_data['TotalCharges'] = pd.to_numeric(telecom_data['TotalCharges'], errors='coerce')

# %%
telecom_data.isnull().sum()
# Out:
# customerID           0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %% [markdown]
# **There is only 11 NAN values in TotalCharges column**

# %%
telecom_data[telecom_data['TotalCharges'].isnull()]
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 488   4472-LVYGI  Female              0     Yes        Yes       0
# 753   3115-CZMZD    Male              0      No        Yes       0
# 936   5709-LVOEQ  Female              0     Yes        Yes       0
# 1082  4367-NUYAO    Male              0     Yes        Yes       0
# 1340  1371-DWPAZ  Female              0     Yes        Yes       0
# 3331  7644-OMVMY    Male              0     Yes        Yes       0
# 3826  3213-VVOLG    Male              0     Yes        Yes       0
# 4380  2520-SGTTA  Female              0     Yes        Yes       0
# 5218  2923-ARZLG    Male              0     Yes        Yes       0
# 6670  4075-WKNIU  Female              0     Yes        Yes       0
# 6754  2775-SEFEE    Male              0      No        Yes       0
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 488            No  No phone service             DSL                  Yes  ...
# ...

# %%
telecom_data.dropna(inplace=True)

# %%
telecom_data.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
telecom_data.count()
# Out:
# customerID          7032
# gender              7032
# SeniorCitizen       7032
# Partner             7032
# Dependents          7032
# tenure              7032
# PhoneService        7032
# MultipleLines       7032
# InternetService     7032
# OnlineSecurity      7032
# OnlineBackup        7032
# DeviceProtection    7032
# TechSupport         7032
# StreamingTV         7032
# StreamingMovies     7032
# Contract            7032
# PaperlessBilling    7032
# PaymentMethod       7032
# MonthlyCharges      7032
# TotalCharges        7032
# Churn               7032
# dtype: int64

# %%
sns.pairplot(data=telecom_data)

# %%
sns.heatmap(data=telecom_data.corr(), annot=True, cmap='RdBu_r')
# Out:
# <AxesSubplot:>

# %% [markdown]
# **We can understand from this that when tenture and monthlycharges increase TotalCharges increases.**

# %%
sns.boxplot(data=telecom_data['TotalCharges'], orient='h')
plt.ylabel('TotalCharges')
# Out:
# Text(0, 0.5, 'TotalCharges')

# %%
sns.boxplot(data=telecom_data[['MonthlyCharges', 'tenure']], orient='h')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Gender Distribution

# %%
gender = (telecom_data['gender'].value_counts() * 100) / len(telecom_data['gender'])
gender
# Out:
# Male      50.469283
# Female    49.530717
# Name: gender, dtype: float64

# %%
gender.index
# Out:
# Index(['Male', 'Female'], dtype='object')

# %%
gender.values
# Out:
# array([50.46928328, 49.53071672])

# %%
sns.barplot(x=gender.index, y=gender.values)
plt.title('Gender Distribution')
plt.ylabel('% Customers')
plt.xlabel('Gender')
# Out:
# Text(0.5, 0, 'Gender')

# %%
senior_citizen = (telecom_data['SeniorCitizen'].value_counts() * 100) / len(telecom_data['SeniorCitizen'])
senior_citizen
# Out:
# 0    83.759954
# 1    16.240046
# Name: SeniorCitizen, dtype: float64

# %%
plt.pie(senior_citizen, labels=['No', 'Yes'], autopct='%1.1f%%')
plt.title('% of Senior Citizens')
# Out:
# Text(0.5, 1.0, '% of Senior Citizens')

# %% [markdown]
# ## Dependents and parteners

# %%
dependents = telecom_data['Dependents'].value_counts() * 100 / len(telecom_data['Dependents'])
print(dependents)
print("=============")

parteners = telecom_data['Partner'].value_counts() * 100 / len(telecom_data['Partner'])
print(parteners)
# Out:
# No     70.150739
# Yes    29.849261
# Name: Dependents, dtype: float64
# ...
# No     51.749147
# Yes    48.250853
# Name: Partner, dtype: float64

# %%
sns.barplot(x=dependents.index, y=dependents.values)
plt.title("% Customers with Dependents")
# Out:
# Text(0.5, 1.0, '% Customers with Dependents')

# %%
sns.barplot(x=parteners.index, y=parteners.values)
plt.title("% Customers with Parteners")
# Out:
# Text(0.5, 1.0, '% Customers with Parteners')

# %% [markdown]
# ###  Customer Account Information

# %%
sns.histplot(data=telecom_data, x='tenure')
plt.ylabel('# of Customers')
plt.xlabel('tenure (months)')
plt.title('# of Customers by thier tenure')
# Out:
# Text(0.5, 1.0, '# of Customers by thier tenure')

# %% [markdown]
# **After looking to the distribution we can see that alot of customers stay with the company for a months and quiet many stay for 72 months.**

# %%
phones = telecom_data['PhoneService'].value_counts() * 100 / len(telecom_data['PhoneService'])
phones
# Out:
# Yes    90.32992
# No      9.67008
# Name: PhoneService, dtype: float64

# %%
sns.barplot(x=phones.index, y=phones.values)
plt.title('% of Customers have a phone service')
# Out:
# Text(0.5, 1.0, '% of Customers have a phone service')

# %%
contract = telecom_data['Contract'].value_counts()
sns.barplot(x=contract.index, y=contract.values)
plt.title('# of Customers by Contract Type')
plt.ylabel('# of Customers')
# Out:
# Text(0, 0.5, '# of Customers')

# %% [markdown]
# **As we can see most of customers are in Month-to-Month Contract.**

# %%
month_to_month = telecom_data[telecom_data['Contract'] == 'Month-to-month']
one_year = telecom_data[telecom_data['Contract'] == 'One year']
two_year = telecom_data[telecom_data['Contract'] == 'Two year']

# %%
fig, (ax1, ax2, ax3) = plt.subplots(nrows=1, ncols=3, figsize=(20, 6), sharey=True)
ax1.set_ylabel('# of Customers')

sns.histplot(data=month_to_month, x='tenure', ax=ax1, color='green')
ax1.set_title('Month-to-Month Contract')
ax1.set_xlabel('tenure (months)')

sns.histplot(data=one_year, x='tenure', ax=ax2, color='red')
ax2.set_title('One Year Contract')
ax2.set_xlabel('tenure (months)')

sns.histplot(data=two_year, x='tenure', ax=ax3, color='blue')
ax3.set_title('Two Year Contract')
ax3.set_xlabel('tenure (months)')
# Out:
# Text(0.5, 0, 'tenure (months)')

# %% [markdown]
# **Most of the monthly contracts last for 1-2 months, while the 2 year contracts tend to last for about 70 months. This shows that the customers taking a longer contract are more loyal to the company and tend to stay with it for a longer period of time.**

# %% [markdown]
# ## Various Services

# %%
services = ['PhoneService','MultipleLines','InternetService','OnlineSecurity',
           'OnlineBackup','DeviceProtection','TechSupport','StreamingTV','StreamingMovies']

fig, axes = plt.subplots(nrows=3, ncols=3, figsize=(20, 12))

for i, item in enumerate(services):
    if i < 3:
        sns.barplot(x=telecom_data[item].value_counts().index, y=telecom_data[item].value_counts().values, ax=axes[i, 0])
        axes[i, 0].set_title(item)
    elif (i >= 3) and (i < 6):
        sns.barplot(x=telecom_data[item].value_counts().index, y=telecom_data[item].value_counts().values, ax=axes[i-3, 1])
        axes[i-3, 1].set_title(item)
    elif i < 9:
        sns.barplot(x=telecom_data[item].value_counts().index, y=telecom_data[item].value_counts().values, ax=axes[i-6, 2])
        axes[i-6, 2].set_title(item)

# %% [markdown]
# ## Churn

# %%
churn = telecom_data['Churn'].value_counts() * 100 / len(telecom_data['Churn'])
churn
# Out:
# No     73.421502
# Yes    26.578498
# Name: Churn, dtype: float64

# %%
sns.barplot(x=churn.index, y=churn.values, palette="Set2")
plt.title('Churn Rate')
plt.ylabel('% of Customers')
# Out:
# Text(0, 0.5, '% of Customers')

# %% [markdown]
# **About 74% of customers don't churn.**

# %%
sns.boxplot(x=telecom_data['Churn'], y=telecom_data['tenure'], palette='Set2')
# Out:
# <AxesSubplot:xlabel='Churn', ylabel='tenure'>

# %% [markdown]
# **We can see that customers who don't churn tend to stay for a longer tenure.**
